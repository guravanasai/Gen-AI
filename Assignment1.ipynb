# %%
## Task 18
attendance = ["Present", "Absent", "Present", "Present", "Absent"]

present_count = 0
absent_count = 0

for status in attendance:
    if status == "Present":
        present_count = present_count + 1
    else:
        absent_count = absent_count + 1

print("Total Present:", present_count)
print("Total Absent:", absent_count)
# Out:
# Total Present: 3
# Total Absent: 2

# %%
## Task 1
scores = [520, 780, 430]

if scores[0] == scores[1] or scores[1] == scores[2] or scores[0] == scores[2]:
    print("Tie Detected")
else:
    if scores[0] > scores[1] and scores[0] > scores[2]:
        first = 0
        if scores[1] > scores[2]:
            second = 1
            third = 2
        else:
            second = 2
            third = 1

    elif scores[1] > scores[0] and scores[1] > scores[2]:
        first = 1
        if scores[0] > scores[2]:
            second = 0
            third = 2
        else:
            second = 2
            third = 0

    else:
        first = 2
        if scores[0] > scores[1]:
            second = 0
            third = 1
        else:
            second = 1
            third = 0

    print("First Rank  : Friend", first + 1, "  Score:", scores[first])
    print("Second Rank : Friend", second + 1, "  Score:", scores[second])
    print("Third Rank  : Friend", third + 1, "  Score:", scores[third])
# Out:
# First Rank  : Friend 2   Score: 780
# Second Rank : Friend 1   Score: 520
# Third Rank  : Friend 3   Score: 430

# %%
#problem-2
orders = ["Veg","Paneer","Veg","Cheese","Paneer","Veg"]
k=set(orders)
print(f"all unique pizza types: {k}")
print(f"unique pizzas ordered are :{len(k)}")
# Out:
# all unique pizza types: {'Veg', 'Paneer', 'Cheese'}
# unique pizzas ordered are :3

# %%
#problem 3
balance = 15000
withdraw = int(input("enter amount:"))
if withdraw<=balance:
    if withdraw<0:
        print("Invalid Amount")
    else:
        print("you are welcome to make withdrawal")
        print("Transaction successful remaining balance:",balance-withdraw)
else:
    print("Insufficient Balance")
# Out:
# enter amount: 20000
# Insufficient Balance

# %%
#problem 4
marks = [96,81,55,74,67,92]
for i in range(len(marks)):
    if marks[i]>=90:
        print(f"student {i+1} got full Scholarship")
    elif 75<=marks[i]<=89:
        print(f"student {i+1} got Half Scholarship")
    elif 60<=marks[i]<=74:
        print(f"student {i+1} need training program")
    else:
        print(f"student {i+1} Better Luck Next Time")
# Out:
# student 1 got full Scholarship
# student 2 got Half Scholarship
# student 3 Better Luck Next Time
# student 4 need training program
# student 5 need training program
# student 6 got full Scholarship

# %%
#problem 5
signal=input("enter signal colour: ")
if signal.lower()=="red":
    print("stop")
elif signal.lower()=="yellow":
    print("Ready")
elif signal.lower()=="green":
    print("Go")
else:
    print("signal error")
# Out:
# enter signal colour:  green
# Go

# %%
#problem 6
prices = [250,180,450,120,600]
max=0
sum=0
min=prices[0]
for i in prices:
    if i>max:
        max=i
    if i<min:
        min=i
    sum+=i
print(f"highest price: {max}")
print(f"Total Bill :{sum}")
print(f"Lowest Price  :{min}")
# Out:
# highest price: 600
# Total Bill :1600
# Lowest Price  :120

# %%
## Task 7
age = 16
ticket = True

if age >= 18 and ticket == True:
    print("Entry Allowed")
else:
    print("Entry Denied")

print()

age = 20
ticket = True
if age >= 18 and ticket == True:
    print("Entry Allowed")
else:
    print("Entry Denied")

print()

age = 25
ticket = False
if age >= 18 and ticket == True:
    print("Entry Allowed")
else:
    print("Entry Denied")
# Out:
# Entry Denied
#
# Entry Allowed
#
# Entry Denied

# %%
## Task 8
books = ["Python", "Java", "Python", "C", "C++", "Java"]

unique_books = set(books)

print("Unique books:", unique_books)
print("Number of unique books:", len(unique_books))

if "Python" in unique_books:
    print("Python exists: Yes")
else:
    print("Python exists: No")
# Out:
# Unique books: {'C', 'Python', 'Java', 'C++'}
# Number of unique books: 4
# Python exists: Yes

# %%
## Task 9
players = ["Ajay", "Ravi", "Ali", "Kiran", "John"]

for player in players:
    if player == "Ali":
        continue
    print(player)
# Out:
# Ajay
# Ravi
# Kiran
# John

# %%
## Task 10
passengers = []
max_seats = 40

for i in range(1, 50):
    if len(passengers) >= max_seats:
        print("Bus Full")
        break
    passengers.append(f"Passenger{i}")

print(f"Total passengers boarded: {len(passengers)}")
# Out:
# Bus Full
# Total passengers boarded: 40

# %%
## Task 11
numbers = [12, 8, 21, 15, 9, 18, 27]

for num in numbers:
    if num % 3 == 0 and num % 7 == 0:
        print(f"Lucky Number Found: {num}")
        break
else:
    print("No lucky number found")
# Out:
# Lucky Number Found: 21

# %%
## Task 12
fruits = ["Apple", "Banana", "Mango", "Orange", "Apple", "Mango"]

if "Mango" in fruits:
    print("Available")
else:
    print("Out of Stock")

unique_fruits = set(fruits)
print("Unique fruits:", unique_fruits)
# Out:
# Available
# Unique fruits: {'Orange', 'Apple', 'Banana', 'Mango'}

# %%
## Task 13
secret_number = 25
guesses = [10, 14, 25, 31, 42]

for guess in guesses:
    if guess == secret_number:
        print("Correct Guess")
        break
    else:
        print(f"Wrong guess: {guess}")
# Out:
# Wrong guess: 10
# Wrong guess: 14
# Correct Guess

# %%
## Task 14
patients = ["Rahul", "Emergency", "Sita", "Ramesh", "Akash"]

for patient in patients:
    if patient == "Emergency":
        print("Treat Immediately")
        break
    else:
        print(f"Processing: {patient}")
# Out:
# Processing: Rahul
# Treat Immediately

# %%
## Task 15
scores = [45, 82, 61, 93, 55, 78]

qualified_count = 0

for score in scores:
    if score >= 60:
        print(f"Score {score}: Qualified")
        qualified_count = qualified_count + 1
    else:
        print(f"Score {score}: Not Qualified")

print(f"Total Qualified: {qualified_count}")
# Out:
# Score 45: Not Qualified
# Score 82: Qualified
# Score 61: Qualified
# Score 93: Qualified
# Score 55: Not Qualified
# Score 78: Qualified
# Total Qualified: 4

# %%
## Task 16
correct_password = "1234"
user_password = "1111"

if user_password == correct_password:
    print("Phone Unlocked")
else:
    print("Wrong Password")
# Out:
# Wrong Password

# %%
## Task 17
fare = 850

if fare > 1000:
    discount = fare * 0.20
    final_fare = fare - discount
elif fare > 500:
    discount = fare * 0.10
    final_fare = fare - discount
else:
    final_fare = fare

print(f"Final Fare: {final_fare}")
# Out:
# Final Fare: 765.0

# %%
## Task 18
attendance = ["Present", "Absent", "Present", "Present", "Absent"]

present_count = 0
absent_count = 0

for status in attendance:
    if status == "Present":
        present_count = present_count + 1
    else:
        absent_count = absent_count + 1

print("Total Present:", present_count)
print("Total Absent:", absent_count)
# Out:
# Total Present: 3
# Total Absent: 2

# %%
## Task 19
countries = ["India", "USA", "India", "Japan", "Germany", "USA", "France"]

unique_countries = set(countries)

print("Unique countries:", unique_countries)
print("Number of countries participating:", len(unique_countries))
# Out:
# Unique countries: {'India', 'USA', 'Japan', 'France', 'Germany'}
# Number of countries participating: 5

# %%
## Task 20
systems = ("Engine", "Fuel", "Navigation", "Communication", "Cooling")
status = ["OK", "OK", "FAIL", "OK", "OK"]

all_ok = True

for i in range(len(systems)):
    if status[i] == "FAIL":
        print(f"System Failed: {systems[i]}")
        print("Launch Aborted!")
        all_ok = False
        break

if all_ok:
    print("Ready for Launch")
# Out:
# System Failed: Navigation
# Launch Aborted!
