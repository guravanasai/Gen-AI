# %%
## Task 1
memories=input("enter you memories in the diary:")
with open("diary.txt","a+") as file:
    file.write("\n"+memories)
    file.seek(0)
    k=file.read()
print(k)
# Out:
# enter you memories in the diary: waiting for that one day...
# hiiiii helloalways dull,i am not happy...nothing special...
# waiting for that one day...

# %%
## Task 2
with open("attendance.txt","r") as file:
    students = file.readlines()
count = len(students)
print("Total Attendance:", count)
# Out:
# Total Attendance: 4

# %%
## Task 3
file = open("orders.txt", "w")#3
file.write("Rice\n")
file.write("Milk\n")
file.write("Bread\n")
file.write("Eggs\n")
file.write("Sugar\n")
file.close()
file = open("orders.txt", "r")
orders = file.readlines()
file.close()
print("Items Purchased:")
for item in orders:
    print(item.strip())
count = len(orders)
print("Total Orders:", count)
# Out:
# Items Purchased:
# Rice
# Milk
# Bread
# Eggs
# Sugar
# Total Orders: 5

# %%
## Task 4
password = input("Enter Password: ")
upper = 0
lower = 0
digits = 0
for ch in password:
    if ch.isupper():
        upper += 1
    elif ch.islower():
        lower += 1
    elif ch.isdigit():
        digits += 1
print("Uppercase Letters:", upper)
print("Lowercase Letters:", lower)
print("Digits:", digits)
if len(password) >= 8 and upper > 0 and lower > 0 and digits > 0:
    print("Strong Password")
else:
    print("Weak Password")
# Out:
# Enter Password:  123@sat
# Uppercase Letters: 0
# Lowercase Letters: 3
# Digits: 3
# Weak Password

# %%
## Task 5
message = "Python is Fun and Python is Powerful"#5
count = message.count("Python")
print("Python appears:", count, "times")
print("Uppercase Message:")
print(message.upper())
modified = message.replace("Powerful", "Amazing")
print("Modified Message:")
print(modified)
# Out:
# Python appears: 2 times
# Uppercase Message:
# PYTHON IS FUN AND PYTHON IS POWERFUL
# Modified Message:
# Python is Fun and Python is Amazing

# %%
## Task 6
city = input("Enter city name: ")
cleaned_city = city.strip().title()
print("Cleaned City Name:", cleaned_city)
# Out:
# Enter city name:  satish
# Cleaned City Name: Satish

# %%
## Task 7
def withdraw(balance, amount):
    if amount <= balance:
        balance = balance - amount
        return balance
    else:
        return "Insufficient Balance"
balance = float(input("Enter Balance: "))
amount = float(input("Enter Withdrawal Amount: "))
result = withdraw(balance, amount)
print("Result:", result)
# Out:
# Enter Balance:  20000
# Enter Withdrawal Amount:  10000
# Result: 10000.0

# %%
## Task 8
def calculate_grade(mark):
    if mark >= 90:
        return "A"
    elif mark >= 75:
        return "B"
    elif mark >= 60:
        return "C"
    else:
        return "F"
mark = int(input("Enter Student Marks: "))
grade = calculate_grade(mark)
print("Grade:", grade)
# Out:
# Enter Student Marks:  56
# Grade: F

# %%
## Task 9
def calculate_bill(price, quantity):#9
    total = price * quantity
    return total
price = float(input("Enter Price of Item: "))
quantity = int(input("Enter Quantity: "))
bill = calculate_bill(price, quantity)
print("\n----- BILL -----")
print("Price per Item : ₹", price)
print("Quantity       :", quantity)
print("Total Bill     : ₹", bill)
# Out:
# Enter Price of Item:  250
# Enter Quantity:  20
# ----- BILL -----
# Price per Item : ₹ 250.0
# Quantity       : 20
# Total Bill     : ₹ 5000.0

# %%
## Task 10
discount = lambda price: price * 0.9
price = float(input("Enter Product Price: "))
final_price = discount(price)
print("Original Price:", price)
print("Price after 10% Discount:", final_price)
# Out:
# Enter Product Price:  100
# Original Price: 100.0
# Price after 10% Discount: 90.0

# %%
## Task 11
area = lambda length, width: length * width
length = float(input("Enter Length: "))
width = float(input("Enter Width: "))
result = area(length, width)
print("Area of Rectangle:", result)
# Out:
# Enter Length:  10
# Enter Width:  20
# Area of Rectangle: 200.0

# %%
## Task 12
check_speed = lambda speed: "Overspeed" if speed > 80 else "Normal Speed"
speed = int(input("Enter Speed: "))
print(check_speed(speed))
# Out:
# Enter Speed:  40
# Normal Speed
