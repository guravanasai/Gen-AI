# %%
students = {     "Rahul": 91,     "Ayesha": 84,     "Kiran": 67,     "Ali": 45 }
pass_count=0
fail_count=0
for name, marks in students.items():
    print(f"Name:{name},Marks:{marks}")
    if marks<=40:
        print("Fail")
        fail_count+=1
    else:
        print("Pass")
        pass_count+=1
print("no of students passed:",pass_count)
print("no of students failed:",fail_count)
# Out:
# Name:Rahul,Marks:91
# Pass
# Name:Ayesha,Marks:84
# Pass
# Name:Kiran,Marks:67
# Pass
# Name:Ali,Marks:45
# Pass
# no of students passed: 4
# no of students failed: 0

# %%
inventory = {"Rice": 20,"Sugar": 15,"Milk": 8,"Eggs": 30} 
item_name=input("enter the item want to buy: ")
if item_name in inventory:
    inventory[item_name]-=1
    print(f"{item_name} purchased")
else:
    print("Item Not Available")
for item,quantity in inventory.items():
    print(item,":",quantity)
# Out:
# enter the item want to buy:  Milk
# Milk purchased
# Rice : 20
# Sugar : 15
# Milk : 7
# Eggs : 30

# %%
users = {     "admin":"python123",     "student":"welcome",     "guest":"guest123" } 

attempts=0
while(attempts<3):
    username=input("enter user name:")
    password=input("enter password:")
    if username in users and  users[username]==password:
        print("Login successful")
        break
    else:
        attempts+=1
        print("Invalid login")
        print("Attempts left:",3-attempts)
if attempts==3:
    print("Account locked")
# Out:
# enter user name: admin
# enter password: 112
# Invalid login
# Attempts left: 2
# enter user name: admin
# enter password: 2
# Invalid login
# Attempts left: 1
# enter user name: as
# enter password: sd
# Invalid login
# Attempts left: 0
# Account locked

# %%
#prob-4
books = {     101:"Python",     102:"Java",     103:"SQL",     104:"Machine Learning" } 
try:
    id=int(input("enter book id:"))
    if book_id in books:
        print(books[book_id])
    else:
        print("book not found")
except ValueError:
    print("Invalid input")
# Out:
# enter book id: 102
# Java

# %%
#prob-5
details={"a":400,"b":300,"c":500}
inp=input("enter user name: ")
if inp in details:
    print(details[inp])
else:
    print("customer not found")
# Out:
# enter user name:  5
# customer not found

# %%
#prob-6
expenses={}
while True:
    name=input("enter name: ")
    if name.lower()=="stop":
        break
    amt=int(input("enter amount:"))
    expenses[name]=amt
for person, amount in expenses.items():
    print(a,":",b)
print("total expences:",len(expenses))
# Out:
# enter name:  a
# enter amount: 2
# enter name:  c
# enter amount: 3
# enter name:  stop
# a : 2
# c : 3
# total expences: 2

# %%
#prob-7
with open("attendence.txt",'a+') as file:
    file.write("Rahul\n")
    file.write("Ayesha\n")
    file.write("Ali\n")
    file.write("Kiran")
    file.seek(0)
    s=file.read()
print(s)
# Out:
# Rahul
# Ayesha
# Ali
# Kiran

# %%
#prob-8
with open("diary.txt",'w') as file:
    file.write(input("enter todays experience:"))
print("diary saved successfully")
# Out:
# enter todays experience: hiiiii hello
# diary saved successfully

# %%
with open("diary.txt",'r') as file:
    k=file.read()
print(k)
# Out:
# hiiiii hello

# %%
#prob-9
try:
    with open("marks.txt","r") as file:
        print(file.read())
except FileNotFoundError:
    print("File Not Found")
# Out:
# File Not Found

# %%
#prob-10
try:
    n1=int(input("enter numerator:"))
    n2=int(input("denominator:"))
    k=n1/n2
    print(k)
except ValueError:
    print("Invalid number entered")
except ZeroDivisionError:
    print("Divide by zero  error")
# Out:
# enter numerator: 2
# denominator: 0
# Divide by zero  error

# %%
#prob-11
scores = { "Rahul":120, "Ali":250, "John":180 } 
max=scores["Rahul"]
for i in scores:
    if scores[i]>max:
        max=scores[i]
print(max)
# Out:
# 250

# %%
#prob-12
patients = { 101:"Rahul", 102:"Sita", 103:"Kiran", 104:"Ali" } 
try:
    id=int(input("enter patient id:"))
    if patient_id in patients:
        print("Name:",patients[patient_id])
    else:
        print("invalid id")
except ValueError:
    print("enter valid id as number")
# Out:
# enter patient id: 105
# invalid id

# %%
#prob-13
seats = {     "A1": "Available",     "A2": "Booked",     "A3": "Available",     "A4": "Available" }
s_no=input("enter seat no: ").title()
if s_no in seats:
    if seats[s_no]!="Booked":
        seats[s_no]="Booked"
        print("seat booked successfully")
    else:
        print("seat already booked")
else:
    print("invalid seat no")
print(seats)
# Out:
# enter seat no:  a5
# invalid seat no
# {'A1': 'Available', 'A2': 'Booked', 'A3': 'Available', 'A4': 'Available'}

# %%
#prob-14
temp=input("entr todays temperature:")
with open("weather.txt","a") as file:
    file.write(temp+"\n")
# Out:
# entr todays temperature: 23

# %%
#prob-15
items = { "Milk":50, "Bread":40, "Eggs":70, "Rice":500 } 
bill = 0  
while True:
    item = input("Enter Item Name : ").title()
    if item.lower() == "done":
        break      
    if item in items:
        bill += items[item] 
        print(item, "Added")
    else: 
        print("Item Not Available")
print("Final Bill:",bill)
# Out:
# Enter Item Name :  milk
# Milk Added
# Enter Item Name :  done
# Final Bill: 50

# %%
#prob-16
fare = {     "Hyderabad":300,     "Warangal":700,     "Karimnagar":600 } 
city = input("Enter Destination: ").title()
if city in fare:
    print("Fare:", fare[city])
else:
    print("Service Not Available")
# Out:
# Enter Destination:  hyderabad
# Fare: 300

# %%
#prob-17
password = input("Create a password: ")

while len(password) < 8:
    print("Password must be at least 8 characters long.")
    password = input("Please try again and create a password: ")

print("Password Accepted")
# Out:
# Create a password:  asdf@234
# Password Accepted

# %%
#prob-18
file_name = "sample.txt"
content = "Hello! Welcome to file handling in Python. Let's count the words in this file."
with open(file_name, "w") as file:
    file.write(content)
with open(file_name, "r") as file:
    file_data = file.read()
words = file_data.split()
total_words = len(words)
print(f"Total words: {total_words}")
# Out:
# Total words: 14

# %%
#prob-19
student_info = {
    "Name": "Aarav",
    "Age": 21,
    "Course": "Computer Science",
    "City": "Mumbai"
}
print("--- Initial Details ---")
print("Dictionary Keys:", list(student_info.keys()))
print("Dictionary Values:", list(student_info.values()))
print("\nProfile Summary:")
for key, value in student_info.items():
    print(f"• {key}: {value}")
student_info.update({"City": "Bangalore"})
print("\n--- Updated Profile Summary ---")
for key, value in student_info.items():
    print(f"• {key}: {value}")
# Out:
# --- Initial Details ---
# Dictionary Keys: ['Name', 'Age', 'Course', 'City']
# Dictionary Values: ['Aarav', 21, 'Computer Science', 'Mumbai']
#
# Profile Summary:
# • Name: Aarav
# • Age: 21
# • Course: Computer Science
# • City: Mumbai
#
# --- Updated Profile Summary ---
# • Name: Aarav
# • Age: 21
# • Course: Computer Science
# • City: Bangalore

# %%
#prob-20
systems = {
    "Engine": "OK",
    "Fuel": "OK",
    "Navigation": "FAIL",
    "Communication": "OK"
}
mission_failed = False
for system, status in systems.items():
    if status == "FAIL":
        print(f"System Failure: {system}")
        with open("mission_log.txt", "w") as file:
            file.write(f"Failure in {system} system.")
            
        print("Mission Aborted.")
        mission_failed = True
        break  
if not mission_failed:
    with open("mission_log.txt", "w") as file:
        file.write("Launch Successful")
    print("All systems clear. Launch Successful!")
# Out:
# System Failure: Navigation
# Mission Aborted.
